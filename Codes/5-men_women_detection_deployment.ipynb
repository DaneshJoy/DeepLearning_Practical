# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp '/content/drive/MyDrive/fine-tuned.keras' 'fine-tuned.keras'
# !cp '/content/drive/MyDrive/final_model_last_epoch.h5' 'final_model_last_epoch.h5'

# %%
from tensorflow.keras.models import load_model

model1 = load_model('fine-tuned.keras')

# %%
from google.colab import files
_ = files.upload()
# Out:
#      <input type="file" id="files-63d1d1af-8e1a-406e-9622-374fed63e797" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-63d1d1af-8e1a-406e-9622-374fed63e797">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

img1 = image.load_img('face_mask_1.jpg', target_size=(180, 180))

# %%
plt.imshow(img1)

# %%
img1_arr = image.img_to_array(img1)
type(img1_arr)
# Out:
# numpy.ndarray

# %%
img1_arr.shape
# Out:
# (180, 180, 3)

# %%
import numpy as np

img1_arr = np.expand_dims(img1_arr, axis=0)
img1_arr.shape
# Out:
# (1, 180, 180, 3)

# %%
pred1 = model1.predict(img1_arr)
# Out:
# 1/1 [==============================] - 0s 368ms/step

# %%
pred1
# Out:
# array([[0.9993963]], dtype=float32)

# %%
plt.imshow(img1)
plt.axis('off')
plt.title('Man' if pred1<0.5 else 'Woman')
plt.show()
