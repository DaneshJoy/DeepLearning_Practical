# %% [markdown]
# # Unsupervised Learning: Convolutional Denoising AutoEncoder
# Remove noise from hand-written digits (MNIST) images

# %%
from tensorflow.keras import layers, optimizers, losses
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras import callbacks
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Parameters

# %%
epochs = 30
batch_size = 256
noise_factor = 0.5

# %% [markdown]
# ## Prepare Data

# %%
(x_train, _), (x_test, _) = mnist.load_data()

# Normalize image pixel values
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# Add gaussian noise to images
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0,
                                                          scale=1.0,
                                                          size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0,
                                                        scale=1.0,
                                                        size=x_test.shape)

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
# Visualize Noisy Data Samples

fig, axes = plt.subplots(1, 5, figsize=(10,2))
for i, ax in enumerate(axes.flat):
    ax.imshow(np.squeeze(x_train_noisy[i]), cmap='gray')
    ax.set_axis_off()
plt.show()

# %% [markdown]
# ## Create Layers + Model

# %%
input_img = layers.Input(shape=(28, 28, 1))
x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (7, 7, 32)

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)

autoencoder.compile(optimizer=optimizers.Adam(learning_rate = 0.003),
                    loss=losses.binary_crossentropy,
                    metrics=['accuracy'])

autoencoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 16)        160
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 16)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 14, 14, 32)        4640
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 7, 7, 32)          9248
#
#  up_sampling2d_2 (UpSampling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 14, 14, 16)        4624
#
#  up_sampling2d_3 (UpSampling  (None, 28, 28, 16)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 1)         145
#
# =================================================================
# Total params: 18,817
# Trainable params: 18,817
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
# Callbacks

model_checkpoint = callbacks.ModelCheckpoint('model_checkpoint.h5',
                                             save_best_only=True)
logger = callbacks.CSVLogger('training.log')
my_callbacks = [model_checkpoint, logger]

# Train the Model

history = autoencoder.fit(x_train_noisy, x_train, epochs=epochs,
                          batch_size=batch_size, shuffle=True,
                          validation_data=(x_test_noisy, x_test),
                          callbacks=my_callbacks)

autoencoder.save('model_final.h5')
# Out:
# Epoch 1/30
# 235/235 [==============================] - 14s 12ms/step - loss: 0.1710 - accuracy: 0.8052 - val_loss: 0.1204 - val_accuracy: 0.8087
# Epoch 2/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1164 - accuracy: 0.8106 - val_loss: 0.1118 - val_accuracy: 0.8112
# Epoch 3/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1102 - accuracy: 0.8116 - val_loss: 0.1074 - val_accuracy: 0.8104
# Epoch 4/30
# 235/235 [==============================] - 2s 11ms/step - loss: 0.1070 - accuracy: 0.8120 - val_loss: 0.1048 - val_accuracy: 0.8116
# Epoch 5/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1049 - accuracy: 0.8123 - val_loss: 0.1031 - val_accuracy: 0.8114
# Epoch 6/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1035 - accuracy: 0.8125 - val_loss: 0.1020 - val_accuracy: 0.8114
# Epoch 7/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1025 - accuracy: 0.8126 - val_loss: 0.1013 - val_accuracy: 0.8115
# Epoch 8/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1017 - accuracy: 0.8127 - val_loss: 0.1005 - val_accuracy: 0.8120
# Epoch 9/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1011 - accuracy: 0.8128 - val_loss: 0.0998 - val_accuracy: 0.8120
# Epoch 10/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1004 - accuracy: 0.8129 - val_loss: 0.0999 - val_accuracy: 0.8114
# Epoch 11/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1000 - accuracy: 0.8130 - val_loss: 0.0992 - val_accuracy: 0.8117
# Epoch 12/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0995 - accuracy: 0.8130 - val_loss: 0.0985 - val_accuracy: 0.8121
# Epoch 13/30
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0992 - accuracy: 0.8131 - val_loss: 0.0984 - val_accuracy: 0.8123
# Epoch 14/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0990 - accuracy: 0.8131 - val_loss: 0.0981 - val_accuracy: 0.8122
# Epoch 15/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0986 - accuracy: 0.8131 - val_loss: 0.0979 - val_accuracy: 0.8123
# Epoch 16/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0984 - accuracy: 0.8131 - val_loss: 0.0976 - val_accuracy: 0.8120
# Epoch 17/30
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0981 - accuracy: 0.8132 - val_loss: 0.0976 - val_accuracy: 0.8123
# Epoch 18/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0979 - accuracy: 0.8132 - val_loss: 0.0972 - val_accuracy: 0.8124
# Epoch 19/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0978 - accuracy: 0.8132 - val_loss: 0.0971 - val_accuracy: 0.8122
# Epoch 20/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0976 - accuracy: 0.8132 - val_loss: 0.0969 - val_accuracy: 0.8123
# Epoch 21/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0975 - accuracy: 0.8133 - val_loss: 0.0973 - val_accuracy: 0.8118
# Epoch 22/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0974 - accuracy: 0.8133 - val_loss: 0.0968 - val_accuracy: 0.8125
# Epoch 23/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0971 - accuracy: 0.8133 - val_loss: 0.0967 - val_accuracy: 0.8120
# Epoch 24/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0970 - accuracy: 0.8133 - val_loss: 0.0966 - val_accuracy: 0.8121
# Epoch 25/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0969 - accuracy: 0.8133 - val_loss: 0.0966 - val_accuracy: 0.8126
# Epoch 26/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0968 - accuracy: 0.8134 - val_loss: 0.0961 - val_accuracy: 0.8123
# Epoch 27/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0966 - accuracy: 0.8134 - val_loss: 0.0962 - val_accuracy: 0.8123
# Epoch 28/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0965 - accuracy: 0.8134 - val_loss: 0.0959 - val_accuracy: 0.8123
# Epoch 29/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0965 - accuracy: 0.8134 - val_loss: 0.0961 - val_accuracy: 0.8121
# Epoch 30/30
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0963 - accuracy: 0.8134 - val_loss: 0.0960 - val_accuracy: 0.8124

# %% [markdown]
# ## Train/Validation Loss/Accuracy Plots

# %%
fig, ax = plt.subplots(1, 2, figsize=(15,5))

ax[0].plot(history.history['loss'], label='Train Loss')
ax[0].plot(history.history['val_loss'], label='Validation Loss')
ax[0].set_xlabel('Epochs')
ax[0].legend()

ax[1].plot(history.history['accuracy'], label='Train accuracy')
ax[1].plot(history.history['val_accuracy'], label='Validation accuracy')
ax[1].set_xlabel('Epochs')
ax[1].legend()

plt.show()

# %% [markdown]
# ## Evaluation

# %%
# Decoder output
decoded_imgs = autoencoder.predict(x_test_noisy)

fig, axes = plt.subplots(1, 10, figsize=(20, 2))
for i, ax in enumerate(axes):
    ax.imshow(x_test_noisy[i].reshape(28, 28), cmap='gray')
    ax.set_axis_off()
plt.suptitle('Noisy Input Images')

fig, axes = plt.subplots(1, 10, figsize=(20, 2))
for i, ax in enumerate(axes):
    ax.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    ax.set_axis_off()
plt.suptitle('Denoising Autoencoder Outputs')

plt.show()

# %% [markdown]
# ## Visualize Encoder Output (Latent Space Representation)

# %%
# Encoder output
encoder_model = Model(input_img, encoded)
encoder_model.summary()
encoded_data = encoder_model.predict(x_test_noisy)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 16)        160
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 16)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 14, 14, 32)        4640
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
# =================================================================
# Total params: 4,800
# Trainable params: 4,800
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.figure(figsize=(2,2))
plt.imshow(x_test_noisy[0].reshape(28, 28), cmap='gray')
plt.title('input image')

fig, axes = plt.subplots(4, 6, figsize=(10, 5))
for i, ax in enumerate(axes.flat):
    ax.imshow(encoded_data[0][:,:,i], cmap='gray')
    ax.set_axis_off()
plt.suptitle('Encoder outputs')
# Out:
# Text(0.5, 0.98, 'Encoder outputs')
